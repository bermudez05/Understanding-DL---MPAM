# %% [markdown]
# <a href="https://colab.research.google.com/github/udlbook/udlbook/blob/main/Notebooks/Chap08/8_1_MNIST_1D_Performance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.1: MNIST_1D_Performance**
#
# This notebook runs a simple neural network on the MNIST1D dataset as in figure 8.2a. It uses code from https://github.com/greydanus/mnist1d to generate the data.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TO DO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# %pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to c:\users\laura\appdata\local\temp\pip-req-build-3fsha31y
#   Resolved https://github.com/greydanus/mnist1d to commit 350929d12f4c9a4b7355e0c96604e41b9239bdb4
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: requests in c:\users\laura\onedrive\documentos\github\understanding-dl---mpam\venv\lib\site-packages (from mnist1d==0.0.2.post9) (2.32.3)
# Requirement already satisfied: numpy in c:\users\laura\onedrive\documentos\github\understanding-dl---mpam\venv\lib\site-packages (from mnist1d==0.0.2.post9) (1.26.4)
# Requirement already satisfied: matplotlib in c:\users\laura\onedrive\documentos\github\understanding-dl---mpam\venv\lib\site-packages (from mnist1d==0.0.2.post9) (3.8.3)
# Requirement already satisfied: scipy in c:\users\laura\onedrive\documentos\github\understanding-dl---mpam\venv\lib\site-packages (from mnist1d==0.0.2.post9) (1.14.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\laura\onedrive\documentos\github\understanding-dl---mpam\venv\lib\site-packages (from matplotlib->mnist1d==0.0.2.post9) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\laura\onedrive\documentos\github\understanding-dl---mpam\venv\lib\site-packages (from matplotlib->mnist1d==0.0.2.post9) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\laura\onedrive\documentos\github\understanding-dl---mpam\venv\lib\site-packages (from matplotlib->mnist1d==0.0.2.post9) (4.50.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\laura\onedrive\documentos\github\understanding-dl---mpam\venv\lib\site-packages (from matplotlib->mnist1d==0.0.2.post9) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\laura\onedrive\documentos\github\understanding-dl---mpam\venv\lib\site-packages (from matplotlib->mnist1d==0.0.2.post9) (24.0)
# Requirement already satisfied: pillow>=8 in c:\users\laura\onedrive\documentos\github\understanding-dl---mpam\venv\lib\site-packages (from matplotlib->mnist1d==0.0.2.post9) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\laura\onedrive\documentos\github\understanding-dl---mpam\venv\lib\site-packages (from matplotlib->mnist1d==0.0.2.post9) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\laura\onedrive\documentos\github\understanding-dl---mpam\venv\lib\site-packages (from matplotlib->mnist1d==0.0.2.post9) (2.9.0.post0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\laura\onedrive\documentos\github\understanding-dl---mpam\venv\lib\site-packages (from requests->mnist1d==0.0.2.post9) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\laura\onedrive\documentos\github\understanding-dl---mpam\venv\lib\site-packages (from requests->mnist1d==0.0.2.post9) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\laura\onedrive\documentos\github\understanding-dl---mpam\venv\lib\site-packages (from requests->mnist1d==0.0.2.post9) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\laura\onedrive\documentos\github\understanding-dl---mpam\venv\lib\site-packages (from requests->mnist1d==0.0.2.post9) (2024.7.4)
# Requirement already satisfied: six>=1.5 in c:\users\laura\onedrive\documentos\github\understanding-dl---mpam\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post9) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d 'C:\Users\laura\AppData\Local\Temp\pip-req-build-3fsha31y'

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d

# %%
# !git clone https://github.com/greydanus/mnist1d
# Out:
# Cloning into 'mnist1d'...

# %% [markdown]
# Let's generate a training and test dataset using the MNIST1D code.  The dataset gets saved as a .pkl file so it doesn't have to be regenerated each time.

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='mnist1d/mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Successfully loaded data from mnist1d/mnist1d_data.pkl
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
D_i = 40    # Input dimensions
D_k = 100   # Hidden dimensions
D_o = 10    # Output dimensions
# TO DO:
# Define a model with two hidden layers of size 100
# And ReLU activations between them
# Replace this line (see Figure 7.8 of book for help):
model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))


def weights_init(layer_in):
  # TO DO:
  # Initialize the parameters with He initialization
  # Replace this line (see figure 7.8 of book for help)
  print("Initializing layer")
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_normal_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)


# Call the function you just defined
model.apply(weights_init)
# Out:
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Sequential(
#   (0): Linear(in_features=40, out_features=100, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=100, out_features=100, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=100, out_features=10, bias=True)
# )

# %%
# choose cross entropy loss function (equation 5.24)
loss_function = torch.nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 10 epochs
scheduler = StepLR(optimizer, step_size=10, gamma=0.5)

x_train = torch.tensor(data['x'].astype('float32'))
y_train = torch.tensor(data['y'].transpose().astype('long'))
x_test= torch.tensor(data['x_test'].astype('float32'))
y_test = torch.tensor(data['y_test'].astype('long'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 50
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_test = np.zeros((n_epoch))
errors_test = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, batch in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = batch
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch.long())
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_test = model(x_test)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_test_class = torch.max(pred_test.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_test[epoch] = 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
  losses_train[epoch] = loss_function(pred_train, y_train.long()).item()
  losses_test[epoch] = loss_function(pred_test, y_test.long()).item()
  print(
    f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  test loss {losses_test[epoch]:.6f}, test error {errors_test[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()
# Out:
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Epoch     0, train loss 1.578649, train error 59.33,  test loss 1.647060, test error 63.80
# Epoch     1, train loss 1.329761, train error 50.85,  test loss 1.466157, test error 59.00
# Epoch     2, train loss 1.165032, train error 41.78,  test loss 1.345000, test error 53.30
# Epoch     3, train loss 1.006065, train error 35.85,  test loss 1.247343, test error 48.50
# Epoch     4, train loss 0.912517, train error 31.72,  test loss 1.226627, test error 46.90
# Epoch     5, train loss 0.771755, train error 26.72,  test loss 1.128220, test error 43.10
# Epoch     6, train loss 0.688801, train error 23.85,  test loss 1.120342, test error 41.70
# Epoch     7, train loss 0.644467, train error 22.50,  test loss 1.080652, test error 40.10
# Epoch     8, train loss 0.569312, train error 19.55,  test loss 1.139197, test error 41.60
# Epoch     9, train loss 0.548790, train error 18.45,  test loss 1.193504, test error 42.40
# Epoch    10, train loss 0.408552, train error 11.72,  test loss 1.044022, test error 38.40
# Epoch    11, train loss 0.371073, train error 10.10,  test loss 1.075224, test error 37.90
# Epoch    12, train loss 0.336347, train error 8.62,  test loss 1.065691, test error 37.80
# Epoch    13, train loss 0.313149, train error 7.62,  test loss 1.093716, test error 38.00
# Epoch    14, train loss 0.282531, train error 6.90,  test loss 1.067161, test error 36.70
# Epoch    15, train loss 0.265185, train error 6.35,  test loss 1.120437, test error 36.70
# Epoch    16, train loss 0.233842, train error 4.82,  test loss 1.123898, test error 37.00
# Epoch    17, train loss 0.226404, train error 5.53,  test loss 1.154724, test error 37.60
# Epoch    18, train loss 0.195857, train error 3.85,  test loss 1.160442, test error 37.50
# Epoch    19, train loss 0.185703, train error 3.55,  test loss 1.186348, test error 37.80
# Epoch    20, train loss 0.151106, train error 1.88,  test loss 1.181510, test error 37.80
# Epoch    21, train loss 0.141481, train error 1.57,  test loss 1.180062, test error 36.50
# Epoch    22, train loss 0.135181, train error 1.35,  test loss 1.196270, test error 36.40
# Epoch    23, train loss 0.129742, train error 1.10,  test loss 1.204229, test error 36.10
# Epoch    24, train loss 0.124610, train error 1.10,  test loss 1.233415, test error 37.30
# Epoch    25, train loss 0.116456, train error 0.75,  test loss 1.223722, test error 36.70
# Epoch    26, train loss 0.111261, train error 0.62,  test loss 1.243401, test error 37.10
# Epoch    27, train loss 0.104281, train error 0.53,  test loss 1.249672, test error 36.60
# Epoch    28, train loss 0.101453, train error 0.68,  test loss 1.262514, test error 36.40
# Epoch    29, train loss 0.095340, train error 0.50,  test loss 1.278478, test error 36.70
# Epoch    30, train loss 0.089645, train error 0.25,  test loss 1.278255, test error 36.60
# Epoch    31, train loss 0.087381, train error 0.28,  test loss 1.285778, test error 36.30
# Epoch    32, train loss 0.085566, train error 0.22,  test loss 1.287975, test error 36.30
# Epoch    33, train loss 0.083540, train error 0.22,  test loss 1.300623, test error 36.70
# Epoch    34, train loss 0.081450, train error 0.20,  test loss 1.303623, test error 36.50
# Epoch    35, train loss 0.080778, train error 0.15,  test loss 1.307094, test error 37.00
# Epoch    36, train loss 0.077889, train error 0.20,  test loss 1.312411, test error 37.10
# Epoch    37, train loss 0.075864, train error 0.20,  test loss 1.320337, test error 36.60
# Epoch    38, train loss 0.074213, train error 0.20,  test loss 1.328564, test error 36.50
# Epoch    39, train loss 0.072623, train error 0.15,  test loss 1.332622, test error 36.70
# Epoch    40, train loss 0.071389, train error 0.15,  test loss 1.333891, test error 36.60
# Epoch    41, train loss 0.070563, train error 0.15,  test loss 1.336183, test error 36.70
# Epoch    42, train loss 0.069722, train error 0.12,  test loss 1.337434, test error 36.80
# Epoch    43, train loss 0.068981, train error 0.12,  test loss 1.341842, test error 36.60
# Epoch    44, train loss 0.068229, train error 0.12,  test loss 1.344279, test error 36.50
# Epoch    45, train loss 0.067530, train error 0.12,  test loss 1.347004, test error 36.50
# Epoch    46, train loss 0.066787, train error 0.12,  test loss 1.351243, test error 36.50
# Epoch    47, train loss 0.066186, train error 0.12,  test loss 1.348553, test error 36.60
# Epoch    48, train loss 0.065367, train error 0.12,  test loss 1.354765, test error 36.50
# Epoch    49, train loss 0.064738, train error 0.12,  test loss 1.355699, test error 36.20

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_test,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Test Error %3.2f'%(errors_train[-1],errors_test[-1]))
ax.legend()
plt.show()

# Plot the results
fig, ax = plt.subplots()
ax.plot(losses_train,'r-',label='train')
ax.plot(losses_test,'b-',label='test')
ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Loss')
ax.set_title('Train loss %3.2f, Test loss %3.2f'%(losses_train[-1],losses_test[-1]))
ax.legend()
plt.show()

# %% [markdown]
# **TO DO**
#
# Play with the model -- try changing the number of layers, hidden units, learning rate, batch size, momentum or anything else you like.  See if you can improve the test results.
#
# Is it a good idea to optimize the hyperparameters in this way?  Will the final result be a good estimate of the true test performance?

# %% [markdown]
# - Optimize Hyperparameters manually might not be as efficient as one might think and the results might not be as good as they could be, maybe thats why we pre-traine models so we can find the right hypermparameters.

# %%
# choose cross entropy loss function (equation 5.24)
loss_function = torch.nn.CrossEntropyLoss()

# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.5)

# object that decreases learning rate by half every 10 epochs
scheduler = StepLR(optimizer, step_size=10, gamma=0.5)

x_train = torch.tensor(data['x'].astype('float32'))
y_train = torch.tensor(data['y'].transpose().astype('long'))
x_test= torch.tensor(data['x_test'].astype('float32'))
y_test = torch.tensor(data['y_test'].astype('long'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 50
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_test = np.zeros((n_epoch))
errors_test = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, batch in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = batch
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch.long())
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_test = model(x_test)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_test_class = torch.max(pred_test.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_test[epoch] = 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
  losses_train[epoch] = loss_function(pred_train, y_train.long()).item()
  losses_test[epoch] = loss_function(pred_test, y_test.long()).item()
  print(
    f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  test loss {losses_test[epoch]:.6f}, test error {errors_test[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()



# ----------------------------------------------------------------------------------------

# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_test,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Test Error %3.2f'%(errors_train[-1],errors_test[-1]))
ax.legend()
plt.show()

# Plot the results
fig, ax = plt.subplots()
ax.plot(losses_train,'r-',label='train')
ax.plot(losses_test,'b-',label='test')
ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Loss')
ax.set_title('Train loss %3.2f, Test loss %3.2f'%(losses_train[-1],losses_test[-1]))
ax.legend()
plt.show()
# Out:
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Epoch     0, train loss 1.798887, train error 68.57,  test loss 1.871912, test error 74.60
# Epoch     1, train loss 1.635493, train error 63.35,  test loss 1.737074, test error 69.40
# Epoch     2, train loss 1.529664, train error 57.22,  test loss 1.647387, test error 65.80
# Epoch     3, train loss 1.463663, train error 55.03,  test loss 1.593457, test error 64.00
# Epoch     4, train loss 1.379791, train error 50.53,  test loss 1.526018, test error 61.20
# Epoch     5, train loss 1.322964, train error 49.00,  test loss 1.490655, test error 59.80
# Epoch     6, train loss 1.259370, train error 45.15,  test loss 1.440425, test error 57.10
# Epoch     7, train loss 1.200189, train error 42.15,  test loss 1.409383, test error 56.30
# Epoch     8, train loss 1.146654, train error 40.83,  test loss 1.367330, test error 54.70
# Epoch     9, train loss 1.097838, train error 38.42,  test loss 1.337626, test error 52.60
# Epoch    10, train loss 1.073149, train error 36.67,  test loss 1.319536, test error 51.50
# Epoch    11, train loss 1.054711, train error 36.28,  test loss 1.305076, test error 50.80
# Epoch    12, train loss 1.032545, train error 35.45,  test loss 1.294265, test error 50.10
# Epoch    13, train loss 1.019136, train error 34.80,  test loss 1.290201, test error 51.00
# Epoch    14, train loss 0.991962, train error 33.95,  test loss 1.271292, test error 49.20
# Epoch    15, train loss 0.976371, train error 32.68,  test loss 1.260486, test error 49.20
# Epoch    16, train loss 0.959958, train error 32.93,  test loss 1.255462, test error 47.50
# Epoch    17, train loss 0.939204, train error 31.45,  test loss 1.244275, test error 48.20
# Epoch    18, train loss 0.927470, train error 31.20,  test loss 1.234877, test error 46.50
# Epoch    19, train loss 0.910151, train error 30.60,  test loss 1.232746, test error 48.30
# Epoch    20, train loss 0.896715, train error 29.25,  test loss 1.222803, test error 47.30
# Epoch    21, train loss 0.889746, train error 29.22,  test loss 1.214859, test error 47.20
# Epoch    22, train loss 0.880346, train error 28.82,  test loss 1.212810, test error 46.20
# Epoch    23, train loss 0.876146, train error 28.85,  test loss 1.215015, test error 47.00
# Epoch    24, train loss 0.868415, train error 28.55,  test loss 1.207159, test error 46.90
# Epoch    25, train loss 0.859628, train error 27.72,  test loss 1.207817, test error 46.20
# Epoch    26, train loss 0.852143, train error 27.93,  test loss 1.201504, test error 47.10
# Epoch    27, train loss 0.844440, train error 27.68,  test loss 1.196076, test error 45.40
# Epoch    28, train loss 0.838191, train error 27.55,  test loss 1.197162, test error 46.40
# Epoch    29, train loss 0.830060, train error 27.03,  test loss 1.194362, test error 45.30
# Epoch    30, train loss 0.824834, train error 26.40,  test loss 1.189689, test error 44.90
# Epoch    31, train loss 0.822601, train error 26.55,  test loss 1.187805, test error 44.50
# Epoch    32, train loss 0.818025, train error 26.20,  test loss 1.188450, test error 44.20
# Epoch    33, train loss 0.816050, train error 26.53,  test loss 1.186105, test error 45.30
# Epoch    34, train loss 0.811607, train error 26.18,  test loss 1.186049, test error 44.70
# Epoch    35, train loss 0.807801, train error 25.70,  test loss 1.183128, test error 44.20
# Epoch    36, train loss 0.804475, train error 25.93,  test loss 1.181855, test error 44.50
# Epoch    37, train loss 0.802137, train error 25.60,  test loss 1.179958, test error 44.30
# Epoch    38, train loss 0.798012, train error 25.32,  test loss 1.181151, test error 44.30
# Epoch    39, train loss 0.794877, train error 25.65,  test loss 1.177196, test error 44.20
# Epoch    40, train loss 0.792552, train error 25.38,  test loss 1.178339, test error 44.20
# Epoch    41, train loss 0.791069, train error 25.22,  test loss 1.176296, test error 43.90
# Epoch    42, train loss 0.789418, train error 25.15,  test loss 1.175327, test error 44.30
# Epoch    43, train loss 0.787684, train error 25.15,  test loss 1.175602, test error 44.20
# Epoch    44, train loss 0.786049, train error 25.22,  test loss 1.175593, test error 44.20
# Epoch    45, train loss 0.784471, train error 25.25,  test loss 1.174095, test error 44.40
# Epoch    46, train loss 0.783212, train error 25.28,  test loss 1.173197, test error 43.90
# Epoch    47, train loss 0.781282, train error 24.93,  test loss 1.173235, test error 43.90
# Epoch    48, train loss 0.779561, train error 24.85,  test loss 1.173552, test error 43.60
# Epoch    49, train loss 0.777949, train error 24.80,  test loss 1.173235, test error 44.00
